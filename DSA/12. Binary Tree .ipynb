# %% [markdown]
# ## `1.` `Easy Level Question ->` `Traversals`

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="" target="_blank" style="color: white; text-decoration: none;">
#     Binary Tree Representation
#    </a>
# </p>

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


root = Node(10)
root.left = Node(5)
root.right = Node(20)

root.left.left = Node(3)
root.left.right = Node(7)


def print_tree(root, level=0):
    if root is not None:
        print_tree(root.right, level + 1)
        print("    " * level + str(root.data))
        print_tree(root.left, level + 1)


print_tree(root)
# Out:
#     20
# 10
#         7
#     5
#         3

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-preorder-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     1.1 Preorder Traversal
#    </a>
# </p>

# %%
from typing import Optional, List

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution:
    def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        result = []
        def dfs(node):
            if not node:
                return
            result.append(node.val)   # Root
            dfs(node.left)            # Left
            dfs(node.right)           # Right
        dfs(root)
        return result

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-preorder-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     1.2
# Inorder Traversal
#    </a>
# </p>

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def inorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        result = []
        def dfs(node):
            if not node:
                return
            dfs(node.left)            # Left
            result.append(node.val)   # Root
            dfs(node.right)           # Right
        dfs(root)
        return result

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-postorder-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     1.3 Postorder Traversal
#    </a>
# </p>

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def postorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        result = []
        def dfs(node):
            if not node:
                return
            dfs(node.left)            # Left
            dfs(node.right)           # Right
            result.append(node.val)   # Root
        dfs(root)
        return result

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-level-order-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     1.4 Level Order Traversal
#    </a>
# </p>

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
from collections import deque
class Solution:
    def levelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:
        ans=[]
        if not root:
            return ans
        dq=deque()
        dq.append(root)
        while dq:
            level=[]
            for _ in range(len(dq)):
              node=dq.popleft()
              level.append(node.data)
              if node.left:
                  dq.append(node.left)
              if node.right:
                  dq.append(node.right)
            ans.append(level)
        return ans

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-preorder-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     1.5 Iterative Preorder Traversal of Binary Tree
#    </a>
# </p>

# %%
from typing import Optional, List

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution:
    def preorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        if not root:
            return []
        stack=[]
        result=[]
        stack.append(root)
        while len(stack)>0:
            root=stack.pop()
            result.append(root.val)
            if root.right:
                 stack.append(root.right)
            if root.left:
                  stack.append(root.left)
        return result

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-inorder-traversal/" target="_blank" style="color: white; text-decoration: none;">
#     1.6 Iterative Inorder Traversal of Binary Tree
#    </a>
# </p>

# %%
from typing import Optional, List

class Solution:
    def inorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        stack = []
        result = []
        while stack:
            while root:
                stack.append(root)
                root = root.left
            root = stack.pop()
            result.append(root.val)
            root = root.right
        return result

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-postorder-traversal/submissions/1948958467/" target="_blank" style="color: white; text-decoration: none;">
#     Iterative Postorder Traversal of Binary Tree
#    </a>
# </p>

# %%
class Solution:
    def postorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        if not root:
            return []
        stack = []
        result = []
        stack.append(root)
        while stack:
            root = stack.pop()
            result.append(root.val)
            if root.left:
                stack.append(root.left)
            if root.right:
                stack.append(root.right)
        return result[::-1]

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-postorder-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     1.7 Post-order Traversal of Binary Tree using 2 stack
#    </a>
# </p>

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-postorder-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     1.8 Post-order Traversal of Binary Tree using 1 stack
#    </a>
# </p>

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="" target="_blank" style="color: white; text-decoration: none;">
#     1.9 Preorder, Inorder, and Postorder Traversal in one Traversal
#    </a>
# </p>

# %% [markdown]
# ## `2.` `Medium Level Question`

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/maximum-depth-of-binary-tree/description/" target="_blank" style="color: white; text-decoration: none;">
#     2.1 Maximum Depth of Binary Tree
#    </a>
# </p>

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
        level=1
        stack=[]
        stack.append((root,1))
        while stack:
            node,depth=stack.pop()
            level=max(level,depth)
            if node.left:
                stack.append((node.left,depth+1))
            if node.right:
                stack.append((node.right,depth+1))
        return level

# %%
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
        if not root:
            return 0
        left=self.maxDepth(root.left)
        right=self.maxDepth(root.right)
        return 1 + max(left,right)

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/balanced-binary-tree/description/" target="_blank" style="color: white; text-decoration: none;">
#     2.2 Balanced Binary Tree
#    </a>
# </p>

# %%
class Solution:

    def maxDepth(self, root):
        if not root:
            return 0
        stack=[(root,1)]
        level=0
        while stack:
            node,depth=stack.pop()
            level=max(level,depth)
            if node.left:
                stack.append((node.left,depth+1))
            if node.right:
                stack.append((node.right,depth+1))
        return level


    def isBalanced(self, root):
        if not root:
            return True
        left_depth = self.maxDepth(root.left)
        right_depth = self.maxDepth(root.right)
        if abs(left_depth - right_depth) > 1:
            return False
        return self.isBalanced(root.left) and self.isBalanced(root.right)

# %%
class Solution:
    def isBalanced(self, root: Optional[TreeNode]) -> bool:
        def height(node):
            if not node:
                return 0
            left = height(node.left)
            right = height(node.right)
            if left == -1 or right == -1:
                return -1
            if abs(left - right) > 1:
                return -1
            return 1 + max(left, right)
        return height(root) != -1

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/diameter-of-binary-tree/description/" target="_blank" style="color: white; text-decoration: none;">
#     2.3 Diameter of Binary Tree
#    </a>
# </p>

# %%
class Solution:
    def diameterOfBinaryTree(self, root: Optional[TreeNode]) -> int:
        self.diameter=0
        def height(node):
            if not node:
                return 0
            left=height(node.left)
            right=height(node.right)
            self.diameter=max(self.diameter,left+right)
            return 1 + max(left,right)
        height(root)
        return self.diameter

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-maximum-path-sum/description/" target="_blank" style="color: white; text-decoration: none;">
#     2.4
# Maximum path sum
#    </a>
# </p>

# %%
class Solution:
    def maxPathSum(self, root: Optional[TreeNode]) -> int:
        self.max_sum = float('-inf')

        def dfs(node):
            if not node:
                return 0
            
            left = max(0, dfs(node.left))
            right = max(0, dfs(node.right))

            self.max_sum = max(self.max_sum, left + right + node.val)

            return node.val + max(left, right)

        dfs(root)
        return self.max_sum

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/same-tree/description/" target="_blank" style="color: white; text-decoration: none;">
#     2.5 Check if two trees are identical or not
#    </a>
# </p>

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isSameTree(self, p: Optional[TreeNode], q: Optional[TreeNode]) -> bool:
        def dfs(node1,node2):
            if not node1 and not node2:
                return True
            if not node1 or not node2 or node1.val != node2.val:
                return False
            return dfs(node1.lrft,node2.left) and dfs(node1.right,node2.right)
        return dfs(p,q)

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-zigzag-level-order-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     2.6 Binary Tree Zigzag Level Order Traversal
#    </a>
# </p>

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def zigzagLevelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:
        if not root:
            return []
        ans=[]
        from collections import deque
        dq = deque([root])
        level_num=0

        while dq:
            level=[]
            for _ in range(len(dq)):
                node=dq.popleft()
                level.append[node]
                if node.left:
                    dq.append(node.left)
                if node.right:
                    dq.append(node.right)
            if level_num % 2 ==0:
                level=level[::-1]
            level_num=level_num+1
            ans.append(level)
        return ans

# %%
from collections import deque

class Solution:
    def zigzagLevelOrder(self, root):
        if not root:
            return []
        ans = []
        dq = deque([root])
        left_to_right = True
        while dq:
            level = deque()
            for _ in range(len(dq)):
                node = dq.popleft()
                if left_to_right:
                    level.append(node.val)
                else:
                    level.appendleft(node.val)
                if node.left:
                    dq.append(node.left)
                if node.right:
                    dq.append(node.right)
            ans.append(list(level))
            left_to_right = not left_to_right
        
        return ans

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://takeuforward.org/plus/dsa/problems/boundary-traversal?source=strivers-a2z-dsa-track" target="_blank" style="color: white; text-decoration: none;">
#     2.7 Boundary Traversal
#    </a>
# </p>

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.data = val
#         self.left = left
#         self.right = right

class Solution:
    def boundary(self, root):
        if not root:
            return []
        
        left_stack=[]
        right_stack=[]

        def is_leaf(node):
            return not node.left and not node.right
        
        # 1. Add root (if not leaf)
        if not is_leaf(root):
            left_stack.append(root.data)

        # 2. Left Boundary
        def left_boundary(node,stack):
            node=node.left
            while node:
                if is_leaf(node)!=True:
                    stack.append(node.data)
                if not node.left:
                    node=node.right
                else:
                    node=node.left

        # 3. add leaf node
        def leaf_node(node,stack):
            if is_leaf(node):
                stack.append(node.data)
            if node.left:
                leaf_node(node.left,stack)
            if node.right:
                leaf_node(node.right,stack)
        
        # 4. right 
        def right_boundary(node,stack,ans):
            node=node.right
            while node:
                if is_leaf(node)!=True:
                    stack.append(node.data)
                if not node.right:
                    node=node.left
                else:
                    node=node.right
            while stack:
                ans.append(stack.pop())
        
        left_boundary(root,left_stack)
        leaf_node(root,left_stack)
        right_boundary(root,right_stack,left_stack)

        return left_stack

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/vertical-order-traversal-of-a-binary-tree/description/" target="_blank" style="color: white; text-decoration: none;">
#     2.8 Vertical Order Traversal
#    </a>
# </p>

# %% [markdown]
# `normal vertical traversal`

# %%
from collections import deque

class Solution:
    def verticalTraversal(self, root):
        if not root:
            return []
        col_map = {}   # normal dict
        q = deque([(root, 0)])
        min_col = 0
        max_col = 0
        while q:
            node, col = q.popleft()
            # manual hashmap handling
            if col not in col_map:
                col_map[col] = []
            col_map[col].append(node.val)

            #  if not uisng hash_map.key() in for loop and uisng - for c in range(min_col, max_col + 1):
            # min_col = min(min_col, col)
            # max_col = max(max_col, col)

            if node.left:
                q.append((node.left, col - 1))
            if node.right:
                q.append((node.right, col + 1))
        # build result
        result = []
        for col in sorted(col_map.keys()): # or for c in range(min_col, max_col + 1):
            result.append(col_map[col])
        return result

# %%
from collections import defaultdict, deque


# Definition for a binary tree node
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def verticalTraversal(self, root):
        col_map = defaultdict(list)
        q = deque([(root, 0, 0)])  # (node, col, row)
        
        while q:
            node, col, row = q.popleft()
            col_map[col].append((row, node.val))
            if node.left:
                q.append((node.left, col - 1, row + 1))
            if node.right:
                q.append((node.right, col + 1, row + 1))
        result = []
        
        print(col_map.keys())
        print(sorted(col_map.keys()))
        for col in sorted(col_map.keys()):
            # sort by row first, then value

            # 
            # print(col_map[col])
            nodes = sorted(col_map[col])
            print(nodes)
            temp = []
            for pair in nodes:
                row = pair[0]
                val = pair[1]
                temp.append(val)
            
            result.append(temp)
        
        return result

# Create tree
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.right = TreeNode(13)
root.right.left = TreeNode(2)


sol = Solution()
print(sol.verticalTraversal(root))
# Out:
# dict_keys([0, -1, 1])
# [-1, 0, 1]
# [(1, 2)]
# [(0, 1), (2, 2), (2, 13)]
# [(1, 3)]
# [[2], [1, 2, 13], [3]]

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://www.geeksforgeeks.org/problems/top-view-of-binary-tree/1" target="_blank" style="color: white; text-decoration: none;">
#     2.9 Top View of BT
#    </a>
# </p>

# %%
'''
class Node:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None
'''
from collections import defaultdict, deque
class Solution:
    def topView(self, root):
        hash_map={}
        ans=[]
        queue=deque([(root,0,0)])

        while queue:
            node,col,row=queue.popleft()
            if col not in hash_map:
                hash_map[col]=[]
            hash_map[col].append([row,node.data])

            if node.left:
                queue.append([node.left,col-1,row+1])
            if node.right:
                queue.append((node.right, col + 1, row + 1))
        
        for col in sorted(hash_map.keys()):
            nodes=hash_map[col]

            top_view_value=nodes[0][1]
            ans.append(top_view_value)
        
        return ans

# %%
from collections import deque

class Solution:
    def verticalTopView(self, root):
        if not root:
            return []
        
        col_map = {}  # store first node only
        q = deque([(root, 0)])  # (node, column)
        
        while q:
            node, col = q.popleft()
            
            if col not in col_map:
                col_map[col] = node.val
            
            if node.left:
                q.append((node.left, col - 1))
            if node.right:
                q.append((node.right, col + 1))
        
        # sort by column
        result = []
        for col in sorted(col_map.keys()):
            result.append(col_map[col])
        
        return result

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://www.geeksforgeeks.org/problems/bottom-view-of-binary-tree/1" target="_blank" style="color: white; text-decoration: none;">
#     2.10 Bottom view of BT
#    </a>
# </p>

# %%
from collections import defaultdict, deque

class Solution:
    def bottomView(self, root):
        hash_map = defaultdict(list)
        q = deque([(root, 0, 0)])  
        
        while q:
            node, col, row = q.popleft()
            hash_map[col].append((row, node.val))
            
            if node.left:
                q.append((node.left, col - 1, row + 1))
            if node.right:
                q.append((node.right, col + 1, row + 1))
        
        ans = []
        
        for col in sorted(hash_map.keys()):
            nodes = hash_map[col]
            ans.append(nodes[-1][1])       
        
        return ans

# %%
from collections import deque

class Solution:
    def bottomView(self, root):
        if not root:
            return []
        
        col_map = {}  # column -> latest value
        q = deque([(root, 0)])  # (node, column)
        
        while q:
            node, col = q.popleft()

            col_map[col] = node.val
            
            if node.left:
                q.append((node.left, col - 1))
            if node.right:
                q.append((node.right, col + 1))
        
        # sort columns
        result = []
        for col in sorted(col_map.keys()):
            result.append(col_map[col])
        
        return result

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-right-side-view/description/" target="_blank" style="color: white; text-decoration: none;">
#     2.11 Right/Left View of Binary Tree
#    </a>
# </p>

# %%
from collections import defaultdict, deque

class Solution:
    def rightSideView(self, root):
        if not root:
            return []
        
        hash_map = defaultdict(list)   # row -> list of nodes
        q = deque([(root, 0)])         # node, row
        
        while q:
            node, row = q.popleft()
            
            hash_map[row].append(node.val)
            
            if node.left:
                q.append((node.left, row + 1))
            if node.right:
                q.append((node.right, row + 1))
        
        ans = []
        
        # process rows in order
        for row in sorted(hash_map.keys()):
            nodes = hash_map[row]
            ans.append(nodes[-1])   
        
        return ans

# %%
from collections import deque

class Solution:
    def rightSideView(self, root):
        if not root:
            return []
        q = deque([root])
        ans = []
        while q:
            size = len(q)
            for i in range(size):
                node = q.popleft()
                if i == size - 1:
                    ans.append(node.val)
                if node.left:
                    q.append(node.left)
                if node.right:
                    q.append(node.right)
        
        return ans

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/symmetric-tree/description/" target="_blank" style="color: white; text-decoration: none;">
#     2.12
# Symmetric Binary Tree
#    </a>
# </p>

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

class Solution(object):
    def isSymmetric(self, root):
        
        def dfs(left, right):
            # both null
            if not left and not right:
                return True
            
            # one null or value mismatch
            if not left or not right or left.val != right.val:
                return False
            
            # mirror comparison
            return dfs(left.left, right.right) and dfs(left.right, right.left)
        
        return dfs(root.left, root.right)

# %% [markdown]
# ## `2.` `Hard Level Question`

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://www.geeksforgeeks.org/problems/root-to-leaf-paths/1" target="_blank" style="color: white; text-decoration: none;">
#     3.1 Print root to leaf path in BT
#    </a>
# </p>

# %%
from typing import Optional
from collections import deque

from typing import List

"""

definition of binary tree node.
class Node:
    def _init_(self,val):
        self.data = val
        self.left = None
        self.right = None
"""

class Solution:
    def Paths(self, root):
        if not root:
            return []
        
        ans=[]
        path=[]

        def dfs(node,path):
            if not node:
                return
            path.append(node.data)

            if not node.left and not node.right:
                ans.append(path[:])
            else:
                dfs(node.left,path)
                dfs(node.right,path)
            
            path.pop()
        
        dfs(root,path)
        return ans

# %%
class Solution:
    def getPath(self, root, path, x):
        if not root:
            return False
        path.append(root.data)
        
        if root.data == x:
            return
        if self.getPath(root.left, path, x) or self.getPath(root.right, path, x):
            return True
        
        path.pop()
        return False
    
    def solve(self, root, x):
        path = []
        if not root:
            return path
        
        self.getPath(root, path, x)
        return path

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/lowest-common-ancestor-of-a-binary-tree/description/" target="_blank" style="color: white; text-decoration: none;">
#     3.2 LCA
#    </a>
# </p>

# %%
class Solution:
    def getPath(self, root, path, x):
        if not root:
            return False
        
        path.append(root)
        if root == x:
            return True
        if self.getPath(root.left, path, x) or self.getPath(root.right, path, x):
            return True
        path.pop()
        return False
    
    
    def lowestCommonAncestor(self, root, p, q):
        path1 = []
        path2 = []
        self.getPath(root, path1, p)
        self.getPath(root, path2, q)
        i = 0
        # find last common node
        while i < len(path1) and i < len(path2):
            if path1[i] != path2[i]:
                break
            i += 1
        return path1[i-1]

# %%
class Solution:
    def lowestCommonAncestor(self, root, p, q):
        
        def dfs(node):
            if not node:
                return None
            
            if node == p or node == q:
                return node
        
            left = dfs(node.left)
            right = dfs(node.right)

            if left and right:
                return node
            
            return left if left else right

        return dfs(root)

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/maximum-width-of-binary-tree/description/" target="_blank" style="color: white; text-decoration: none;">
#     3.3 Maximum Width of BT
#    </a>
# </p>

# %%
class Solution:
    # Function to calculate maximum width
    def widthOfBinaryTree(self, root):

        if not root:
            return 0
        max_width = 0
        q = deque()
        q.append((root, 0))

        while q:
            size = len(q)
            min_index = q[0][1]
            first = 0
            last = 0

            # Process all nodes at this level
            for i in range(size):

                # Get node and relative index
                node, idx = q.popleft()
                curr_index = idx - min_index

                if i == 0: first = curr_index
                if i == size - 1:  last = curr_index

                if node.left:
                    q.append((node.left, 2 * curr_index + 1))
                if node.right:
                    q.append((node.right, 2 * curr_index + 2))

            max_width = max(max_width, last - first + 1)

        return max_width
# Out:
# [(3, 'left'), (3, 'right'), (3, 'right')]

# %% [markdown]
#         1
#        / \
#       2   3
#      /     \
#     4       5
#    /         /
#   6         7

# %%
from collections import deque

class Solution:
    def widthOfBinaryTree(self, root):
        if not root:
            return 0
        
        max_width = 0
        q = deque([(root, 0)])  # (node, index)
        
        while q:
            size = len(q)
            _, first = q[0]
            
            for i in range(size):
                node, idx = q.popleft()
                
                if node.left:
                    q.append((node.left, 2 * idx))
                if node.right:
                    q.append((node.right, 2 * idx + 1))
                
                if i == size - 1:
                    max_width = max(max_width, idx - first + 1)
        
        return max_width

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://www.geeksforgeeks.org/problems/children-sum-parent/1" target="_blank" style="color: white; text-decoration: none;">
#     3.4 Children Sum Property in Binary Tree
#    </a>
# </p>

# %%
'''
# Node Class:
class Node:
    def init(self,val):
        self.data = val
        self.left = None
        self.right = None
'''

class Solution:
    def isSumProperty(self, root):
        
        if not root:
            return True
            
        if not root.left and not root.right:
            return True
            
        left_val = root.left.data if root.left else 0
        right_val = root.right.data if root.right else 0
            
        if root.data == left_val+right_val:
            return (self.isSumProperty(root.left) and self.isSumProperty(root.right))
        
        return False

              
      
# Create nodes
root = Node(35)

root.left = Node(20)
root.right = Node(15)

root.left.left = Node(15)
root.left.right = Node(5)

root.right.left = Node(10)
root.right.right = Node(5)

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/all-nodes-distance-k-in-binary-tree/description/" target="_blank" style="color: white; text-decoration: none;">
#     3.5 Print all nodes at a distance of K in BT
#    </a>
# </p>

# %%
from collections import deque
from typing import List, Optional

# Definition for a binary tree node
class TreeNode:
    def __init__(self, x: int):
        self.val = x
        self.left: Optional[TreeNode] = None
        self.right: Optional[TreeNode] = None

class Solution:
    def distanceK(self, root: TreeNode, target: TreeNode, k: int) -> List[int]:
        # Edge case: empty tree
        if not root:
            return []

        # Step 1: Build a map of each node's parent
        parent_map = {}
        self.map_parents(root, parent_map)

        # Step 2: Run BFS from the target node to find all nodes at distance K
        return self.bfs_from_target(target, parent_map, k)

    # This method builds a mapping of each node to its parent using BFS
    def map_parents(self, root: TreeNode, parent_map: dict):
        queue = deque()
        queue.append(root)

        while queue:
            node = queue.popleft()
            # If left child exists, record its parent and add it to the queue
            if node.left:
                parent_map[node.left] = node
                queue.append(node.left)
            # If right child exists, record its parent and add it to the queue
            if node.right:
                parent_map[node.right] = node
                queue.append(node.right)

    # This method performs BFS starting from the target node to find nodes at distance K
    def bfs_from_target(self, target: TreeNode, parent_map: dict, k: int) -> List[int]:
        queue = deque()
        visited = set()

        queue.append(target)
        visited.add(target)

        current_level = 0

        # Standard BFS loop
        while queue:
            if current_level == k:
                break

            level_size = len(queue)
            for _ in range(level_size):
                node = queue.popleft()

                # Check left child
                if node.left and node.left not in visited:
                    visited.add(node.left)
                    queue.append(node.left)

                # Check right child
                if node.right and node.right not in visited:
                    visited.add(node.right)
                    queue.append(node.right)

                # Check parent node
                # If the parent exists and hasn't been visited, add it to the queue
                if node in parent_map and parent_map[node] not in visited:
                    visited.add(parent_map[node])
                    queue.append(parent_map[node])

            current_level += 1

        return [node.val for node in queue]

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://www.geeksforgeeks.org/problems/burning-tree/1" target="_blank" style="color: white; text-decoration: none;">
#     3.6 Minimum time taken to burn the BT from a given Node
#    </a>
# </p>

# %%
from collections import deque

class Solution:
    def minTime(self, root, target):

        parent_map = {}
        target_node = self.map_parents(root, parent_map, target)
        
        return self.bfs(target_node, parent_map)

    
    def map_parents(self, root, parent_map, target):
        queue = deque([root])
        target_node = None
        
        while queue:
            node = queue.popleft()
            
            if node.data == target:
                target_node = node
            
            if node.left:
                parent_map[node.left] = node
                queue.append(node.left)
            
            if node.right:
                parent_map[node.right] = node
                queue.append(node.right)
        
        return target_node
    
    def map_parents(self, root, parent_map, target):
        self.target_node = None
        
        def dfs(node, parent):
            if not node:
                return
            
            # map parent
            if parent:
                parent_map[node] = parent
            
            # check target
            if node.data == target:
                self.target_node = node
            
            # go left & right
            dfs(node.left, node)
            dfs(node.right, node)
        
        dfs(root, None)
        return self.target_node


    def bfs(self, target_node, parent_map):
        queue = deque([target_node])
        visited = set([target_node])
        
        time = 0
        
        while queue:
            size = len(queue)
            burned = False   
            
            for _ in range(size):
                node = queue.popleft()
                
                if node.left and node.left not in visited:
                    visited.add(node.left)
                    queue.append(node.left)
                    burned = True

                if node.right and node.right not in visited:
                    visited.add(node.right)
                    queue.append(node.right)
                    burned = True

                if node in parent_map and parent_map[node] not in visited:
                    visited.add(parent_map[node])
                    queue.append(parent_map[node])
                    burned = True
            
            if burned:
                time += 1
        
        return time

# %% [markdown]
# `an algo , which is very hard to think by own`

# %%
class Solution:
    def minTime(self, root, target):
        self.ans = 0
        
        def dfs(node):
            if not node:
                return -1
            
            # target found
            if node.data == target:
                self.burn_down(node, 0)
                return 1
            
            left = dfs(node.left)
            right = dfs(node.right)
            
            # if target in left subtree
            if left != -1:
                self.ans = max(self.ans, left)
                self.burn_other(node.right, left + 1)
                return left + 1
            
            # if target in right subtree
            if right != -1:
                self.ans = max(self.ans, right)
                self.burn_other(node.left, right + 1)
                return right + 1
            
            return -1
        
        # burn downward subtree
        def burn_down(node, time):
            if not node:
                return
            self.ans = max(self.ans, time)
            burn_down(node.left, time + 1)
            burn_down(node.right, time + 1)
        
        # burn opposite subtree
        def burn_other(node, time):
            if not node:
                return
            self.ans = max(self.ans, time)
            burn_other(node.left, time + 1)
            burn_other(node.right, time + 1)
        
        dfs(root)
        return self.ans

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/count-complete-tree-nodes/description/" target="_blank" style="color: white; text-decoration: none;">
#     3.7 Count total nodes in a complete BT
#    </a>
# </p>

# %%
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution:
    def countNodes(self, root):
        if not root:
            return 0
        
        lh = self.findHeightLeft(root)
        rh = self.findHeightRight(root)

        # If heights match, it's a perfect binary tree
        if lh == rh:
            return (1 << lh) - 1
        # Otherwise, recursively count left and right subtrees
        return 1 + self.countNodes(root.left) + self.countNodes(root.right)

    def findHeightLeft(self, node):
        height = 0
        while node:
            height += 1
            node = node.left
        return height

    def findHeightRight(self, node):
        height = 0
        while node:
            height += 1
            node = node.right
        return height

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://www.geeksforgeeks.org/problems/unique-binary-tree-requirements/1" target="_blank" style="color: white; text-decoration: none;">
#     3.8 Requirements needed to construct a unique BT
#    </a>
# </p>

# %%
class Solution:
    def isPossible(self, a, b):
        if (a == 2 and b != 2) or (b == 2 and a != 2):
            return True
        return False

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/construct-binary-tree-from-preorder-and-inorder-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     3.9 Construct a BT from Preorder and Inorder
#    </a>
# </p>

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

class Solution:
    def buildTree(self, preorder, inorder):
        # hashmap for inorder index
        hash_map={}
        for i in range(len(inorder)):
            hash_map[inorder[i]]=i
        self.parent_index=0
        def build_tree(left,right):
            if left > right:
                return None
            root_val=preorder[self.parent_index]
            self.parent_index=self.parent_index+1
            mid=hash_map[root_val]

            root=TreeNode(root_val)
            root.left=build_tree(left,mid-1)
            root.right=build_tree(mid+1,right)

            return root 
        return build_tree(0,len(inorder)-1)
# Out:
# 4

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/construct-binary-tree-from-inorder-and-postorder-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     3.10 Construct the Binary Tree from Postorder and Inorder Traversal
#    </a>
# </p>

# %%
class Solution:
    def buildTree(self, inorder, postorder):
        # hashmap for inorder index
        hash_map = {}
        for i in range(len(inorder)):
            hash_map[inorder[i]] = i
        # start from last index
        self.post_idx = len(postorder) - 1
        def build_tree(left, right):
            if left > right:
                return None
            # pick root from postorder
            root_val = postorder[self.post_idx]
            self.post_idx -= 1
            root = TreeNode(root_val)
            mid = hash_map[root_val]
            # ⚠️ IMPORTANT: build right first
            root.right = build_tree(mid + 1, right)
            root.left = build_tree(left, mid - 1)
            return root
        return build_tree(0, len(inorder) - 1)

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/serialize-and-deserialize-binary-tree/description/" target="_blank" style="color: white; text-decoration: none;">
#     3.11 Serialize and De-serialize BT
#    </a>
# </p>

# %%
def inorder(root):
    if not root:
        return
    inorder(root.left)
    print(root.val, end=" ")
    inorder(root.right)

class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
from collections import deque
class Codec:

    def serialize(self, root):
        if not root:
            return ""
        
        string=""
        q=deque([root])

        while q:
            node=q.popleft()
            if node:
                string=string+str(node.val)+","
                q.append(node.left)
                q.append(node.right)
            else:
                string=string+"#,"
        return string[:-1]

    def deserialize(self, data):
        if not data:
            return None
        result = []
        temp = ""
        for ch in data:
            if ch == ",":
                result.append(temp)
                temp = ""
            else:
                temp += ch
        result.append(temp)
        # or result=data.split(",")

        root=TreeNode(int(result[0]))

        q = deque()
        q.append(root)

        i = 1
        while q and i < len(result) - 1:
            current = q.popleft()

            if result[i] != "#":
                left = TreeNode(int(result[i]))
                current.left = left
                q.append(left)
            i += 1

            if result[i] != "#":
                right = TreeNode(int(result[i]))
                current.right = right
                q.append(right)
            i += 1
        return root

# Driver code
if __name__ == "__main__":

    root = TreeNode(1)
    root.left = TreeNode(2)
    root.right = TreeNode(3)
    root.right.left = TreeNode(4)
    root.right.right = TreeNode(5)
    solution = Codec()
    print("Orignal Tree: ", end="")
    inorder(root)
    print()
    serialized = solution.serialize(root)
    print("Serialized:", serialized)
    deserialized = solution.deserialize(serialized)
    print("Tree after deserialisation: ", end="")
    inorder(deserialized)
    print()
# Out:
# Orignal Tree: 2 1 4 3 5
# Serialized: 1,2,3,#,#,4,5,#,#,#,#
# Tree after deserialisation: 2 1 4 3 5

# %%
string="1,2,3,4,54,5,6343"
print(string.split(","))
result = []
item_temp = ""

for ch in string:
    if ch == ",": # means the previous string value visited add into result
        result.append(item_temp)
        item_temp = "" 
    else:
        item_temp += ch # temp helps to store element like 6343,54 while using loop for appending string elemenmt we can track the elemnt more than size one that why we use temp will add temp untill "," comma is not there 

# last element add करना जरूरी है
result.append(item_temp)

print(result)
# Out:
# ['1', '2', '3', '4', '54', '5', '6343']
# ['1', '2', '3', '4', '54', '5', '6343']

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-inorder-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     3.12 Morris Preorder Traversal of a Binary Tree
#    </a>
# </p>

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/binary-tree-inorder-traversal/description/" target="_blank" style="color: white; text-decoration: none;">
#     3.13
# Morris Inorder Traversal of a Binary Tree
#    </a>
# </p>

# %% [markdown]
# <p style="display: inline-block; background-color:rgb(53, 53, 53); color: white; padding: 5px 10px; border-radius: 5px; font-size: 22px;">
#     <a href="https://leetcode.com/problems/flatten-binary-tree-to-linked-list/description/" target="_blank" style="color: white; text-decoration: none;">
#     3.14
# Flatten Binary Tree to Linked List
#    </a>
# </p>

# %% [markdown]
# `Brute force`

# %%
class Solution:
    def flatten(self, root):
        if not root:
            return
        
        nodes = []
        
        # Step 1: Preorder traversal
        def preorder(node):
            if not node:
                return
            nodes.append(node)
            preorder(node.left)
            preorder(node.right)
        
        preorder(root)
        
        # Step 2: Rebuild linked list
        for i in range(len(nodes) - 1):
            nodes[i].left = None
            nodes[i].right = nodes[i + 1]
        
        # last node
        nodes[-1].left = None
        nodes[-1].right = None

# %% [markdown]
# `Optimal approach`

# %%
class Solution:
    def flatten(self, root):
        self.prev = None
        
        def dfs(node):
            if not node:
                return
            
            # process right first
            dfs(node.right)
            dfs(node.left)
            
            # rewire pointers
            node.right = self.prev
            node.left = None
            
            # move prev
            self.prev = node
        
        dfs(root)

# %%
class Solution:
    def flatten(self, root):
        
        def helper(node):
            if not node:
                return None
            
            left_tail = helper(node.left)
            right_tail = helper(node.right)
            
            if left_tail:
                left_tail.right = node.right
                node.right = node.left
                node.left = None
            
            return right_tail or left_tail or node
        
        helper(root)
